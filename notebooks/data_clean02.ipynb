# %%
import pandas as pd
import ast

# %%
df=pd.read_csv(r'D:\Desktop\ML\employee_salary\src\data\raw\us.csv')
df.sample()
# Out:
#            e::Category'  'tag': 'engineering-jobs'}"  \
# 174592              NaN                    126282.39
#
#                                                 215877.61  \
# 174592  {'__CLASS__': 'Adzuna::API::Response::Company'...
#
#                             Adzuna::API::Response::Job  \
# 174592  Project Manager - Regulatory and SEC Reporting
#
#        Position: Research Engineer Location: 100% Remote Duration: Contract Job ID: 178628 Job Overview: 1. 6 years of experience (or equivalent) in research engineering, ML engineering, or systems/software engineering with ML implementation work. 2. Coding background in Python, PyTorch and SQL 3. Publications of their work and experience giving presentations at top conferences showcasing their research 4. Soft Skills - Looking for someone that has a high attention to detail, go-getter personality, te…  \
# 174592  Role Title: Project Manager - SEC & REG Report...
#
#                   5825873821  \
# 174592  2026-07-29T17:25:41Z
# ...

# %%
df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['    e::Category'', ' 'tag': 'engineering-jobs'}"', '215877.61',
#        'Adzuna::API::Response::Job',
#        'Position: Research Engineer Location: 100% Remote Duration: Contract Job ID: 178628 Job Overview: 1. 6 years of experience (or equivalent) in research engineering, ML engineering, or systems/software engineering with ML implementation work. 2. Coding background in Python, PyTorch and SQL 3. Publications of their work and experience giving presentations at top conferences showcasing their research 4. Soft Skills - Looking for someone that has a high attention to detail, go-getter personality, te…',
#        '5825873821',
#        'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTgyNTg3MzgyMSIsInMiOiI2SUZxZEo2TzhSR0dnT19uMHJtZGlRIn0.MTzIRXgwluf3sKsljPjOF94_Q9dkvrHhWl65LIWmEdE',
#        '{'__CLASS__': 'Adzuna::API::Response::Company', 'display_name': 'Pinnacle Technical Resources'}',
#        '-122.180633', 'Software Engineer IV',
# ...

# %%
with open(r'D:\Desktop\ML\employee_salary\src\data\raw\us.csv',
          "r",
          encoding="utf-8") as f:

    for i in range(5):
        print(f.readline())
# Out:
#     e::Category', 'tag': 'engineering-jobs'}",215877.61,Adzuna::API::Response::Job,"Position: Research Engineer Location: 100% Remote Duration: Contract Job ID: 178628 Job Overview: 1. 6 years of experience (or equivalent) in research engineering, ML engineering, or systems/software engineering with ML implementation work. 2. Coding background in Python, PyTorch and SQL 3. Publications of their work and experience giving presentations at top conferences showcasing their research 4. Soft Skills - Looking for someone that has a high attention to detail, go-getter personality, te…",5825873821,eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTgyNTg3MzgyMSIsInMiOiI2SUZxZEo2TzhSR0dnT19uMHJtZGlRIn0.MTzIRXgwluf3sKsljPjOF94_Q9dkvrHhWl65LIWmEdE,"{'__CLASS__': 'Adzuna::API::Response::Company', 'display_name': 'Pinnacle Technical Resources'}",-122.180633,Software Engineer IV,"{'area': ['US', 'California', 'San Mateo County', 'Menlo Park'], 'display_name': 'Menlo Park, San Mateo County', '__CLASS__': 'Adzuna::API::
# ...

# %%
from pathlib import Path

for file in Path(r"D:\Desktop\ML\employee_salary\src\data\raw").glob("*.csv"):
    with open(file, "r", encoding="utf-8") as f:
        print(file.name)
        print(f.readline())
        print("-" * 80)
# Out:
# au.csv
# redirect_url,contract_time,created,salary_is_predicted,title,adref,category,salary_min,location,longitude,description,company,__CLASS__,salary_max,id,latitude,contract_type
#
# --------------------------------------------------------------------------------
# ca.csv
# title,company,salary_is_predicted,location,redirect_url,latitude,created,description,__CLASS__,id,longitude,adref,category,contract_time,contract_type,salary_min,salary_max
#
# --------------------------------------------------------------------------------
# in.csv
# company,location,adref,title,category,salary_is_predicted,redirect_url,id,latitude,description,contract_type,created,__CLASS__,longitude,contract_time
#
# --------------------------------------------------------------------------------
# mx.csv
# category,adref,company,location,title,salary_is_predicted,redirect_url,id,description,latitude,__CLASS__,longitude,created,salary_max,salary_min
#
# ...

# %%
csv_path = RAW_DATA_DIR / f"{country}.csv"

header = not csv_path.exists()

df.to_csv(
    csv_path,
    mode="a",
    index=False,
    header=header
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 csv_path = RAW_DATA_DIR / f"{country}.csv"
#       2
#       3 header = not csv_path.exists()
#       4
#
# NameError: name 'RAW_DATA_DIR' is not defined

# %%
df['company']=df['company'].apply(ast.literal_eval)
df['company']=df['company'].apply(lambda x:x['display_name'] )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Desktop\ML\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...

# %%
header = "title,company,salary_is_predicted,location,redirect_url,latitude,created,description,__CLASS__,id,longitude,adref,category,contract_time,contract_type,salary_min,salary_max\n"

with open("us.csv", "r", encoding="utf-8") as f:
    data = f.read()

with open("us_fixed.csv", "w", encoding="utf-8") as f:
    f.write(header)
    f.write(data)

# %%
import pandas as pd

header = [
    "latitude",
    "category",
    "salary_max",
    "__CLASS__",
    "description",
    "id",
    "adref",
    "company",
    "longitude",
    "title",
    "location",
    "redirect_url",
    "created",
    "salary_min",
    "salary_is_predicted",
    "contract_time",
    "contract_type"
]

df = pd.read_csv(
    r"D:\Desktop\ML\employee_salary\src\data\raw\us.csv",
    names=header,      # Use our own header
    header=None        # Tell pandas the file has no header
)

print(df.head())

df.to_csv(
    r"D:\Desktop\ML\employee_salary\src\data\raw\us_fixed.csv",
    index=False
)

print("US dataset repaired successfully.")
# Out:
#            latitude                                           category  \
# 0      e::Category'                        'tag': 'engineering-jobs'}"
# 1         42.364083  {'tag': 'it-jobs', '__CLASS__': 'Adzuna::API::...
# 2         38.908569  {'label': 'IT Jobs', '__CLASS__': 'Adzuna::API...
# 3         33.922235  {'tag': 'it-jobs', 'label': 'IT Jobs', '__CLAS...
# 4           47.6829  {'tag': 'it-jobs', 'label': 'IT Jobs', '__CLAS...
#
#   salary_max                   __CLASS__  \
# 0  215877.61  Adzuna::API::Response::Job
# 1   93078.22  Adzuna::API::Response::Job
# 2  199662.72  Adzuna::API::Response::Job
# 3  216432.12  Adzuna::API::Response::Job
# 4  240462.83  Adzuna::API::Response::Job
#
#                                          description          id  \
# 0  Position: Research Engineer Location: 100% Rem...  5825873821
# 1  Job Title Senior Mainframe Software Engineer (...  5825873792
# 2  The Solutions Architect will design and delive...  5825873783
# ...

# %%
print(df.columns)
# Out:
# Index(['latitude', 'category', 'salary_max', '__CLASS__', 'description', 'id',
#        'adref', 'company', 'longitude', 'title', 'location', 'redirect_url',
#        'created', 'salary_min', 'salary_is_predicted', 'contract_time',
#        'contract_type'],
#       dtype='str')

# %%
df.head()
# Out:
#            latitude                                           category  \
# 0      e::Category'                        'tag': 'engineering-jobs'}"
# 1         42.364083  {'tag': 'it-jobs', '__CLASS__': 'Adzuna::API::...
# 2         38.908569  {'label': 'IT Jobs', '__CLASS__': 'Adzuna::API...
# 3         33.922235  {'tag': 'it-jobs', 'label': 'IT Jobs', '__CLAS...
# 4           47.6829  {'tag': 'it-jobs', 'label': 'IT Jobs', '__CLAS...
#
#   salary_max                   __CLASS__  \
# 0  215877.61  Adzuna::API::Response::Job
# 1   93078.22  Adzuna::API::Response::Job
# 2  199662.72  Adzuna::API::Response::Job
# 3  216432.12  Adzuna::API::Response::Job
# 4  240462.83  Adzuna::API::Response::Job
#
#                                          description          id  \
# 0  Position: Research Engineer Location: 100% Rem...  5825873821
# 1  Job Title Senior Mainframe Software Engineer (...  5825873792
# 2  The Solutions Architect will design and delive...  5825873783
# ...

# %%
df = df.iloc[1:].reset_index(drop=True)

# %%
df.to_csv(
    r"D:\Desktop\ML\employee_salary\src\data\raw\repair_us.csv",
    index=False
)
